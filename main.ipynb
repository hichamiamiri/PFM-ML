# %%
import requests 
from bs4 import BeautifulSoup
import csv

url = "https://www.moteur.ma/fr/voiture/achat-voiture-occasion"
headers = {
    'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36'
}

base_url = url

while True:

    response = requests.get(base_url, headers=headers)

    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        
        #* Get page pagination
        pagination = soup.find('li', class_='page pagination').find_all('a')
        pagination = pagination[1:-1]
        base_url = pagination[-1]['href']
        
        #* after removing the first and last elements, check if pagination is empty
  

        while len(pagination) > 0:
            #* remove all the previouse visited pages
            pagination = pagination[1:]
            #* fetch the page
            page_response = requests.get(pagination[0]['href'], headers=headers)

            #* fetch cars data 
            page = BeautifulSoup(page_response.text, 'html.parser')
    
            products = page.find_all('div', class_='row bloc-info')
            # urls = products.find_all('a', class_=')
            
            print(len(products))
            
            with open('car_urls.csv', mode='a', newline='', encoding='utf-8') as file:
                writer = csv.writer(file)
                writer.writerow(['URL'])  # Write header

                for product in products:
                    url_tag = product.find('a', class_='slide')
                    if url_tag and url_tag.has_attr('href'):
                        car_url = url_tag['href']
                        print(car_url)
                        print("***************")
                        writer.writerow([car_url])  # Write to CSV inside the loop


        print(len(pagination))
        print("DONE")
          
        
    else:
        print("Failed to retrieve the webpage. Status code:", response.status_code)
# Out:
# 30
# https://www.moteur.ma/fr/voiture/achat-voiture-occasion/detail-annonce/467252/volkswagen-tiguan-.html
# ***************
# https://www.moteur.ma/fr/voiture/achat-voiture-occasion/detail-annonce/467959/porsche-cayenne-.html
# ***************
# https://www.moteur.ma/fr/voiture/achat-voiture-occasion/detail-annonce/467254/volkswagen-tiguan-.html
# ***************
# https://www.moteur.ma/fr/voiture/achat-voiture-occasion/detail-annonce/463178/audi-q8-.html
# ***************
# https://www.moteur.ma/fr/voiture/achat-voiture-occasion/detail-annonce/469011/skoda-kodiaq-.html
# ***************
# https://www.moteur.ma/fr/voiture/achat-voiture-occasion/detail-annonce/466206/hyundai-i20-.html
# ***************
# https://www.moteur.ma/fr/voiture/achat-voiture-occasion/detail-annonce/466207/volkswagen-t-roc-.html
# ***************
# https://www.moteur.ma/fr/voiture/achat-voiture-occasion/detail-annonce/466213/citroen-c3-.html
# ***************
# ...
